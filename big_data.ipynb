# %% [markdown]
# # <b><font color='green'>教育大數據的檔案區(Educational big data)檔案區</font>

# %% [markdown]
# ![03.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# <b><font color='blue'>「大數據」</font></b>是指更龐大且更複雜的資料集，尤其是源自於新資料來源的資料集。這些資料集過於龐大，因此傳統的資料處理軟體已無力招架。但靠著這些巨量資料，您先前無法一直解決的業務問題或許有機會迎刃而解。
#
# <b><font color='red'>教育大數據</font></b>係來自蒐集大量有關學生、家長、教師和職員的數位化活動數據，之後轉化為資訊，再據以研擬學校改進的建議計畫。
